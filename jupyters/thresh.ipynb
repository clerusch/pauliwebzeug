# %%
import stim as s

# %%
c = s.Circuit()
# First Z meas
c.append("H", [7,9,10])
c.append("CNOT",[7,0])
c.append("CNOT",[10,5])
c.append("CNOT",[10,11])
c.append("CNOT",[9,6])
c.append("CNOT",[9,10])
c.append("CNOT",[10,8])
c.append("CNOT",[7,9])
c.append("CNOT",[10,7])
c.append("CNOT",[9,8])
c.append("CNOT",[7,11])
c.append("CNOT",[9,11])
c.append("CNOT",[7,1])
c.append("CNOT",[8,2])
c.append("CNOT",[9,3])
c.append("CNOT",[10,4])
c.append("H", [10,9,8,7])
c.append("MR", [11,10,9,8,7])
c.append("DETECTOR", [s.target_rec(-5)])
# First X meas
c.append("H", [8,11])
c.append("CNOT",[0,7])
c.append("CNOT",[5,10])
c.append("CNOT",[11,10])
c.append("CNOT",[6,9])
c.append("CNOT",[10,9])
c.append("CNOT",[8,10])
c.append("CNOT",[9,7])
c.append("CNOT",[7,10])
c.append("CNOT",[8,9])
c.append("CNOT",[11,7])
c.append("CNOT",[11,9])
c.append("CNOT",[1,7])
c.append("CNOT",[2,8])
c.append("CNOT",[3,9])
c.append("CNOT",[4,10])
c.append("H", [11])
c.append("MR", [11,10,9,8,7])
# Second Z meas
c.append("H", [7,9,10])
c.append("CNOT",[7,0])
c.append("CNOT",[10,5])
c.append("CNOT",[10,11])
c.append("CNOT",[9,6])
c.append("CNOT",[9,10])
c.append("CNOT",[10,8])
c.append("CNOT",[7,9])
c.append("CNOT",[10,7])
c.append("CNOT",[9,8])
c.append("CNOT",[7,11])
c.append("CNOT",[9,11])
c.append("CNOT",[7,1])
c.append("CNOT",[8,2])
c.append("CNOT",[9,3])
c.append("CNOT",[10,4])
c.append("H", [10,9,8,7])
c.append("MR", [11,10,9,8,7])
# Second X meas
c.append("H", [8,11])
c.append("CNOT",[0,7])
c.append("CNOT",[5,10])
c.append("CNOT",[11,10])
c.append("CNOT",[6,9])
c.append("CNOT",[10,9])
c.append("CNOT",[8,10])
c.append("CNOT",[9,7])
c.append("CNOT",[7,10])
c.append("CNOT",[8,9])
c.append("CNOT",[11,7])
c.append("CNOT",[11,9])
c.append("CNOT",[1,7])
c.append("CNOT",[2,8])
c.append("CNOT",[3,9])
c.append("CNOT",[4,10])
c.append("H", [11])
c.append("MR", [11,10,9,8,7])

c.diagram()
# Out:
#  q0: ---X------------------------------------------------------@-------------------------------------X-----------------------------------------------@------------------------------------
#         |                                                      |                                     |                                               |
#  q1: ---|-----------------X------------------------------------|-----------------@-------------------|-----------------X-----------------------------|-----------------@------------------
#         |                 |                                    |                 |                   |                 |                             |                 |
#  q2: ---|-----------------|-X----------------------------------|-----------------|-@-----------------|-----------------|-X---------------------------|-----------------|-@----------------
# ...
